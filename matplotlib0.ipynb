# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import NullFormatter # useful for 'logit'scale

# Fixing random state for reproducibility
np.random.seed(19680801)
# make up some data in the interval ]0, 1[
y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

# plot with various axes scales
plt.figure(1)

# linear
plt.subplot(221)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)


# log
plt.subplot(222)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)


# symmetric log
plt.subplot(223)
plt.plot(x, y - y.mean())
plt.yscale('symlog', linthreshy=0.01)
plt.title('symlog')
plt.grid(True)

# logit
plt.subplot(224)
plt.plot(x, y)
plt.yscale('logit')
plt.title('logit')
plt.grid(True)
# Format the minor tick labels of the y-axis into empty strings with
# 'NullFormatter', to avoid cumbering the axis with too many labels.
plt.gca().yaxis.set_minor_formatter(NullFormatter())
# Adjust the subplot layout, because the logit one may take more space
# than usual, due to y-tick labels like "1 - 10^{-3}"
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25,
                   wspace=0.35)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
img = mpimg.imread('E:\Jupyter\Desert.png')
print(img)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-0cf822a115ac> in <module>
#       3 import matplotlib.image as mpimg
#       4 import numpy as np
# ----> 5 img = mpimg.imread('E:\Jupyter\Desert.png')
#       6 print(img)
#
# c:\program files\python37-32\lib\site-packages\matplotlib\image.py in imread(fname, format)
#    1365         else:
#    1366             with open(fname, 'rb') as fd:
# -> 1367                 return handler(fd)
#    1368     else:
#    1369         return handler(fname)
#
# ValueError: invalid PNG header

# %%
from scipy.misc import imread, imsave, imresize

img = imread('cat.jpg')
print(img.dtype, img.shape)

img_tinted = img * [1, 0.95, 0.9]
img_tinted = imresize(img_tinted, (300, 300))
imsave('cat_tinted.jpg', img_tinted)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-ce31fc012096> in <module>
# ----> 1 from scipy.misc import imread, imsave, imresize
#       2
#       3 img = imread('cat.jpg')
#       4 print(img.dtype, img.shape)
#       5
#
# ImportError: cannot import name 'imread' from 'scipy.misc' (c:\program files\python37-32\lib\site-packages\scipy\misc\__init__.py)
